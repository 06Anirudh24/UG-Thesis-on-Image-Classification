# %%
# !pip install bing-image-downloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bing_image_downloader import downloader

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path = "/content/gdrive/MyDrive/Data Sets - Colab/UTS Thesis/Tree Sketches" #Location to store the images.

# %%
query_string = "tree sketches black and white" #String to be searched for.

# %%
downloader.download(query_string, limit=300,  output_dir=path, 
adult_filter_off=True, force_replace=False, timeout=60)
# Out:
# [%] Downloading Images to /content/gdrive/MyDrive/Data Sets - Colab/UTS Thesis/Tree Sketches/tree sketches black and white
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 17 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://getdrawings.com/images/simple-tree-line-drawing-3.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/736x/50/92/e5/5092e5b6c6258260d80c293df31a27a4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.istockphoto.com/vectors/hand-drawn-tree-sketch-black-and-white-drawing-vector-illustration-vector-id983355384?s=170667a
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://render.fineartamerica.com/images/rendered/square-product/small/images/artworkimages/mediumlarge/1/black-and-white-sketch-tree-debra-lynch.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://paintingvalley.com/sketches/tree-sketch-simple-7.jpg
# [%] File Downloaded !
#
# ...
